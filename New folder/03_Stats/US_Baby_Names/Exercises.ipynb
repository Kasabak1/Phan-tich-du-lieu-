# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv('us_baby.tsv', sep=',')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
print(baby_names.head(10))
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names = baby_names.drop(['Unnamed: 0', 'Id'], axis=1)
print(baby_names.head())
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
gender_counts = baby_names['Gender'].value_counts()
print(gender_counts)
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names = baby_names.drop(['Gender', 'Year'], axis=1, errors='ignore').groupby('Name').sum()
print(names.head())
# Out:
#                                                      State  Count
# Name
# Aaban                                                 NYNY     12
# Aadan                                             CACACATX     23
# Aadarsh                                                 IL      5
# Aaden    ALALALALALALALARARARAZAZAZAZAZAZCACACACACACACA...   3426
# Aadhav                                                  CA      6

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
print(len(names))
# Out:
# 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
most_frequent_name = names['Count'].idxmax()
print("Tên xuất hiện nhiều nhất:", most_frequent_name)
# Out:
# Tên xuất hiện nhiều nhất: Jacob

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
least_count = names['Count'].min()
least_frequent_names = names[names['Count'] == least_count]
print("Số lượng tên xuất hiện ít nhất:", len(least_frequent_names))
# Out:
# Số lượng tên xuất hiện ít nhất: 2578

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
median_occurrence = names['Count'].median()
print("Trung vị (Median):", median_occurrence)
# Out:
# Trung vị (Median): 49.0

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
std_occurrence = names['Count'].std()
print("Độ lệch chuẩn (Standard Deviation):", std_occurrence)
# Out:
# Độ lệch chuẩn (Standard Deviation): 11006.06946789057

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
print(names.describe())
# Out:
#                Count
# count   17632.000000
# mean     2008.932169
# std     11006.069468
# min         5.000000
# 25%        11.000000
# 50%        49.000000
# 75%       337.000000
# max    242874.000000
