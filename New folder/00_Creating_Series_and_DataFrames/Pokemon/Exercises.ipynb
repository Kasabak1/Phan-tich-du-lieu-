# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
pokemon = pd.read_csv('pokemon.csv')

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
print(pokemon.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[['Name', 'Type 1', 'HP', 'Generation', '#']]
pokemon.columns = ['name', 'type', 'hp', 'evolution', 'pokedex']
print(pokemon.head())
# Out:
#                     name   type  hp  evolution  pokedex
# 0              Bulbasaur  Grass  45          1        1
# 1                Ivysaur  Grass  60          1        2
# 2               Venusaur  Grass  80          1        3
# 3  VenusaurMega Venusaur  Grass  80          1        3
# 4             Charmander   Fire  39          1        4

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon['place'] = np.random.choice(['Forest', 'Cave', 'Sea', 'Mountain'], size=len(pokemon))
print(pokemon.head())
# Out:
#                     name   type  hp  evolution  pokedex     place
# 0              Bulbasaur  Grass  45          1        1    Forest
# 1                Ivysaur  Grass  60          1        2  Mountain
# 2               Venusaur  Grass  80          1        3      Cave
# 3  VenusaurMega Venusaur  Grass  80          1        3    Forest
# 4             Charmander   Fire  39          1        4  Mountain

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
print(pokemon.dtypes)
# Out:
# name           str
# type           str
# hp           int64
# evolution    int64
# pokedex      int64
# place          str
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.
